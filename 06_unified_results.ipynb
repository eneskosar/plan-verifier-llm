# %% [markdown]
# # 06 — Unified Results
#
# Loads raw prediction arrays from all evaluation notebooks and recomputes
# all metrics uniformly. No dependency on pre-saved metric files.
#
# ## Sources
# - `raw_preds_flant5.json` — from `02_eval_flant5.ipynb`
# - `raw_preds_gpt41mini.json` — from `03_eval_gpt41mini.ipynb`
# - `raw_preds_gpt5.json` — from `05_gpt5_results.ipynb`
#
# ## Prerequisites
# Run notebooks 02, 03, 05 first.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, json
import numpy as np
from sklearn.metrics import (accuracy_score, f1_score,
                              confusion_matrix, classification_report)

ROOT        = '/content/drive/MyDrive/paper_codes/paper2'
RESULTS_DIR = f'{ROOT}/results'

DOMAINS    = ['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']
DOM_SHORT  = ['bw', 'bw3', 'mys', 'mys3', 'log']
DOM_MAP    = dict(zip(DOMAINS, DOM_SHORT))

DIRECT_CONDS   = ['FlanT5_Direct', 'FlanT5_Direct_FT50', 'FlanT5_Direct_FT_Random',
                  'G_direct', 'G5_direct']
STEPWISE_CONDS = ['FlanT5_Stepwise', 'FlanT5_Stepwise_FT_FOLIO',
                  'FlanT5_Stepwise_FT_PB', 'FlanT5_Stepwise_FT_Combined',
                  'G_stepwise', 'G5_stepwise']

print(f'RESULTS_DIR: {RESULTS_DIR}')
print('Files:', sorted(os.listdir(RESULTS_DIR)))
# Out:
# RESULTS_DIR: /content/drive/MyDrive/paper_codes/paper2/results
# Files: ['ckpt_G5_direct_blocksworld.json', 'ckpt_G5_direct_blocksworld_3.json', 'ckpt_G5_direct_logistics.json', 'ckpt_G5_direct_mystery.json', 'ckpt_G5_direct_mystery_3.json', 'ckpt_G5_stepwise_blocksworld.json', 'ckpt_G5_stepwise_blocksworld_3.json', 'ckpt_G5_stepwise_logistics.json', 'ckpt_G5_stepwise_mystery.json', 'ckpt_G5_stepwise_mystery_3.json', 'ckpt_G_direct_blocksworld.json', 'ckpt_G_direct_blocksworld_3.json', 'ckpt_G_direct_logistics.json', 'ckpt_G_direct_mystery.json', 'ckpt_G_direct_mystery_3.json', 'ckpt_G_stepwise_blocksworld.json', 'ckpt_G_stepwise_blocksworld_3.json', 'ckpt_G_stepwise_logistics.json', 'ckpt_G_stepwise_mystery.json', 'ckpt_G_stepwise_mystery_3.json', 'phase4_results.json', 'raw_preds_flant5.json', 'raw_preds_gpt41mini.json', 'raw_preds_gpt5.json', 'results_flant5.json', 'results_gpt5.json']

# %% [markdown]
# ## 1. Load Raw Predictions

# %%
raw_all = {}

for fname in ['raw_preds_flant5.json',
              'raw_preds_gpt41mini.json',
              'raw_preds_gpt5.json']:
    path = os.path.join(RESULTS_DIR, fname)
    if os.path.exists(path):
        data = json.load(open(path))
        raw_all.update(data)
        print(f'Loaded {fname}: {list(data.keys())}')
    else:
        print(f'MISSING: {fname}')

def get_arrays(cond, domain):
    """
    Get prediction arrays for a condition/domain.
    Handles key name variants across notebooks:
      failing_step_golds / fail_step_golds  (both used in different notebooks)
      failing_step_preds / fail_step_preds
    Returns dict with normalised keys, empty lists if missing.
    """
    r = raw_all.get(cond, {}).get(domain, {})
    pg  = r.get('plan_golds',   [])
    pp  = r.get('plan_preds',   [])
    ag  = r.get('action_golds', [])
    ap  = r.get('action_preds', [])
    # Failing step — try both key name variants
    fsg = (r.get('fail_step_golds') or
           r.get('failing_step_golds') or [])
    fsp = (r.get('fail_step_preds') or
           r.get('failing_step_preds') or [])
    return {'pg': pg, 'pp': pp, 'ag': ag, 'ap': ap, 'fsg': fsg, 'fsp': fsp}

print()
print('Conditions loaded:', list(raw_all.keys()))
# Out:
# Loaded raw_preds_flant5.json: ['FlanT5_Direct', 'FlanT5_Direct_FT50', 'FlanT5_Direct_FT_Random', 'FlanT5_Stepwise', 'FlanT5_Stepwise_FT_FOLIO', 'FlanT5_Stepwise_FT_PB', 'FlanT5_Stepwise_FT_Combined']
# Loaded raw_preds_gpt41mini.json: ['G_direct', 'G_stepwise']
# Loaded raw_preds_gpt5.json: ['G5_direct', 'G5_stepwise']
#
# Conditions loaded: ['FlanT5_Direct', 'FlanT5_Direct_FT50', 'FlanT5_Direct_FT_Random', 'FlanT5_Stepwise', 'FlanT5_Stepwise_FT_FOLIO', 'FlanT5_Stepwise_FT_PB', 'FlanT5_Stepwise_FT_Combined', 'G_direct', 'G_stepwise', 'G5_direct', 'G5_stepwise']

# %% [markdown]
# ## 2. Compute Metrics

# %%
def compute(pg, pp, ag, ap, fsg, fsp):
    """Compute all metrics from raw prediction arrays."""
    if not pg:
        return None

    plan_f1  = f1_score(pg, pp, average='macro', zero_division=0)
    plan_acc = accuracy_score(pg, pp)
    plan_cm  = confusion_matrix(pg, pp, labels=[0, 1]).tolist()

    act_f1 = act_acc = act_cm = None
    if ag:
        act_f1  = f1_score(ag, ap, average='macro', zero_division=0)
        act_acc = accuracy_score(ag, ap)
        act_cm  = confusion_matrix(ag, ap, labels=[0, 1]).tolist()

    fs_acc = None
    if fsg:
        fs_acc = sum(g == p for g, p in zip(fsg, fsp)) / len(fsg)

    return {
        'n_plans'          : len(pg),
        'n_actions'        : len(ag),
        'n_fs_evaluated'   : len(fsg),
        'plan_f1'          : round(plan_f1,  4),
        'plan_acc'         : round(plan_acc, 4),
        'plan_cm'          : plan_cm,
        'action_f1'        : round(act_f1,  4) if act_f1  is not None else None,
        'action_acc'       : round(act_acc, 4) if act_acc is not None else None,
        'action_cm'        : act_cm,
        'failing_step_acc' : round(fs_acc,  4) if fs_acc  is not None else None,
        'plan_golds'       : pg,  'plan_preds'  : pp,
        'action_golds'     : ag,  'action_preds': ap,
        'fail_step_golds'  : fsg, 'fail_step_preds': fsp,
    }

# Compute metrics for every condition and domain
all_results = {}
for cond in DIRECT_CONDS + STEPWISE_CONDS:
    if cond not in raw_all:
        continue
    all_results[cond] = {}
    for domain in DOMAINS:
        arrays = get_arrays(cond, domain)
        r = compute(**arrays)
        if r:
            all_results[cond][domain] = r

print('Metrics computed for:')
for cond, dom_res in all_results.items():
    domains_done = list(dom_res.keys())
    fs_done = [d for d in domains_done
               if all_results[cond][d]['failing_step_acc'] is not None]
    print(f'  {cond:<40s} domains={domains_done}  fs_acc_domains={fs_done}')
# Out:
# Metrics computed for:
#   FlanT5_Direct                            domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']  fs_acc_domains=[]
#   FlanT5_Direct_FT50                       domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']  fs_acc_domains=[]
#   FlanT5_Direct_FT_Random                  domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']  fs_acc_domains=[]
#   G_direct                                 domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']  fs_acc_domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']
#   G5_direct                                domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']  fs_acc_domains=[]
#   FlanT5_Stepwise                          domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']  fs_acc_domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']
#   FlanT5_Stepwise_FT_FOLIO                 domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']  fs_acc_domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']
#   FlanT5_Stepwise_FT_PB                    domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']  fs_acc_domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']
#   FlanT5_Stepwise_FT_Combined              domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']  fs_acc_domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']
#   G_stepwise                               domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']  fs_acc_domains=[]
#   G5_stepwise                              domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']  fs_acc_domains=['blocksworld', 'blocksworld_3', 'mystery', 'mystery_3', 'logistics']

# %% [markdown]
# ## 3. Summary Tables

# %%
SEP  = '-' * 92
SEP2 = '=' * 92

def print_table(title, cond_names, metric):
    active = [c for c in cond_names
              if c in all_results and
              any(all_results[c].get(d, {}).get(metric) is not None
                  for d in DOMAINS)]
    if not active:
        return
    print(f'\n{SEP}')
    print(title)
    print(f'{"Condition":<40s}' +
          ''.join(f'{s:>8s}' for s in DOM_SHORT) +
          f'  {"Mean":>6s}')
    print(SEP)
    for cond in active:
        vals  = [all_results[cond].get(d, {}).get(metric) for d in DOMAINS]
        valid = [v for v in vals if v is not None]
        mean  = np.mean(valid) if valid else float('nan')
        row   = f'{cond:<40s}' + ''.join(
            f'{v:>8.4f}' if v is not None else f'{"N/A":>8s}'
            for v in vals)
        print(row + f'  {mean:>6.4f}')

print(SEP2)
print('PLAN F1-MACRO')
print(SEP2)
print_table('Direct',   DIRECT_CONDS,   'plan_f1')
print_table('Stepwise', STEPWISE_CONDS, 'plan_f1')

print()
print(SEP2)
print('PLAN ACCURACY')
print(SEP2)
print_table('Direct',   DIRECT_CONDS,   'plan_acc')
print_table('Stepwise', STEPWISE_CONDS, 'plan_acc')

print()
print(SEP2)
print('ACTION F1-MACRO')
print(SEP2)
print_table('Direct',   DIRECT_CONDS,   'action_f1')
print_table('Stepwise', STEPWISE_CONDS, 'action_f1')

print()
print(SEP2)
print('ACTION ACCURACY')
print(SEP2)
print_table('Direct',   DIRECT_CONDS,   'action_acc')
print_table('Stepwise', STEPWISE_CONDS, 'action_acc')

print()
print(SEP2)
print('FAILING STEP ACCURACY')
print(SEP2)
print_table('Direct',   DIRECT_CONDS,   'failing_step_acc')
print_table('Stepwise', STEPWISE_CONDS, 'failing_step_acc')

print()
print('NOTE: FT_Random evaluated on own 20% holdout — not directly comparable.')
# Out:
# ============================================================================================
# PLAN F1-MACRO
# ============================================================================================
#
# --------------------------------------------------------------------------------------------
# Direct
# Condition                                     bw     bw3     mys    mys3     log    Mean
# --------------------------------------------------------------------------------------------
# FlanT5_Direct                             0.6244  0.6318  0.2440  0.2992  0.4507  0.4500
# FlanT5_Direct_FT50                        0.2464  0.3904  0.2464  0.3047  0.3982  0.3172
# FlanT5_Direct_FT_Random                   0.2460  0.3913  0.2460  0.3077  0.3956  0.3173
# G_direct                                  0.3806  0.5869  0.2460  0.3265  0.4528  0.3986
# G5_direct                                 0.9077  0.8937  0.4003  0.3574  0.6630  0.6444
#
# --------------------------------------------------------------------------------------------
# Stepwise
# Condition                                     bw     bw3     mys    mys3     log    Mean
# --------------------------------------------------------------------------------------------
# FlanT5_Stepwise                           0.2728  0.3877  0.2464  0.3047  0.3982  0.3220
# FlanT5_Stepwise_FT_FOLIO                  0.3268  0.5182  0.4091  0.4854  0.7663  0.5012
# FlanT5_Stepwise_FT_PB                     0.3817  0.7068  0.2638  0.3267  0.9668  0.5292
# FlanT5_Stepwise_FT_Combined               0.9806  0.9394  0.5661  0.8638  0.9754  0.8651
# G_stepwise                                0.7238  0.8875  0.2464  0.3047  0.5233  0.5371
# G5_stepwise                               0.9764  1.0000  0.5915  0.8427  0.9836  0.8788
#
# ============================================================================================
# PLAN ACCURACY
# ============================================================================================
#
# --------------------------------------------------------------------------------------------
# Direct
# Condition                                     bw     bw3     mys    mys3     log    Mean
# --------------------------------------------------------------------------------------------
# FlanT5_Direct                             0.6245  0.7050  0.3228  0.4270  0.6582  0.5475
# FlanT5_Direct_FT50                        0.3270  0.6403  0.3270  0.4382  0.6618  0.4789
# FlanT5_Direct_FT_Random                   0.3263  0.6429  0.3263  0.4444  0.6545  0.4789
# G_direct                                  0.4047  0.6715  0.3263  0.4483  0.6777  0.5057
# G5_direct                                 0.9216  0.8978  0.4131  0.4023  0.6777  0.6625
#
# --------------------------------------------------------------------------------------------
# Stepwise
# Condition                                     bw     bw3     mys    mys3     log    Mean
# --------------------------------------------------------------------------------------------
# FlanT5_Stepwise                           0.3418  0.6331  0.3270  0.4382  0.6618  0.4804
# FlanT5_Stepwise_FT_FOLIO                  0.3692  0.6475  0.4304  0.5169  0.8218  0.5572
# FlanT5_Stepwise_FT_PB                     0.4156  0.7770  0.3376  0.4494  0.9709  0.5901
# FlanT5_Stepwise_FT_Combined               0.9831  0.9424  0.5675  0.8652  0.9782  0.8673
# G_stepwise                                0.7257  0.8993  0.3270  0.4382  0.7055  0.6191
# G5_stepwise                               0.9789  1.0000  0.5928  0.8427  0.9855  0.8800
#
# ============================================================================================
# ACTION F1-MACRO
# ============================================================================================
#
# --------------------------------------------------------------------------------------------
# Direct
# Condition                                     bw     bw3     mys    mys3     log    Mean
# --------------------------------------------------------------------------------------------
# G_direct                                  0.6271  0.6991  0.5675  0.5769  0.6875  0.6316
#
# --------------------------------------------------------------------------------------------
# Stepwise
# Condition                                     bw     bw3     mys    mys3     log    Mean
# --------------------------------------------------------------------------------------------
# FlanT5_Stepwise                           0.4345  0.4176  0.1397  0.1604  0.2484  0.2801
# FlanT5_Stepwise_FT_FOLIO                  0.3760  0.3450  0.4961  0.4301  0.5444  0.4383
# FlanT5_Stepwise_FT_PB                     0.6162  0.7784  0.4894  0.4798  0.7404  0.6208
# FlanT5_Stepwise_FT_Combined               0.7613  0.7803  0.5670  0.5473  0.6220  0.6556
# G_stepwise                                0.7610  0.8346  0.3303  0.3382  0.7047  0.5938
# G5_stepwise                               0.9757  1.0000  0.6745  0.8404  0.9620  0.8905
#
# ============================================================================================
# ACTION ACCURACY
# ============================================================================================
#
# --------------------------------------------------------------------------------------------
# Direct
# Condition                                     bw     bw3     mys    mys3     log    Mean
# --------------------------------------------------------------------------------------------
# G_direct                                  0.8770  0.8351  0.9405  0.7815  0.9564  0.8781
#
# --------------------------------------------------------------------------------------------
# Stepwise
# Condition                                     bw     bw3     mys    mys3     log    Mean
# --------------------------------------------------------------------------------------------
# FlanT5_Stepwise                           0.5347  0.4979  0.1624  0.1910  0.2690  0.3310
# FlanT5_Stepwise_FT_FOLIO                  0.5521  0.5100  0.8172  0.7124  0.9497  0.7083
# FlanT5_Stepwise_FT_PB                     0.8178  0.8756  0.6648  0.6193  0.9848  0.7925
# FlanT5_Stepwise_FT_Combined               0.9739  0.9216  0.8769  0.8893  0.9832  0.9290
# G_stepwise                                0.9365  0.9272  0.3316  0.3398  0.8806  0.6831
# G5_stepwise                               0.9960  1.0000  0.8455  0.9311  0.9969  0.9539
#
# ============================================================================================
# FAILING STEP ACCURACY
# ============================================================================================
#
# --------------------------------------------------------------------------------------------
# Direct
# Condition                                     bw     bw3     mys    mys3     log    Mean
# --------------------------------------------------------------------------------------------
# G_direct                                  0.7117  0.5909  0.1441  0.4815  0.7857  0.5428
#
# --------------------------------------------------------------------------------------------
# Stepwise
# Condition                                     bw     bw3     mys    mys3     log    Mean
# --------------------------------------------------------------------------------------------
# FlanT5_Stepwise                           1.0000  0.4412  0.6875  0.6071  0.7590  0.6990
# FlanT5_Stepwise_FT_FOLIO                  1.0000  0.0588  0.7037  0.3333  0.7333  0.5658
# FlanT5_Stepwise_FT_PB                     1.0000  0.8421  0.7385  0.7143  1.0000  0.8590
# FlanT5_Stepwise_FT_Combined               1.0000  1.0000  0.8974  1.0000  1.0000  0.9795
# G5_stepwise                               1.0000  1.0000  0.9643  1.0000  1.0000  0.9929
#
# NOTE: FT_Random evaluated on own 20% holdout — not directly comparable.

# %% [markdown]
# ## 4. Plan-Level Confusion Matrices

# %%
SEP3 = '=' * 74

def print_plan_cm(cond_names):
    for cond in cond_names:
        if cond not in all_results:
            continue
        print(f'\n{SEP3}')
        print(f'PLAN CM — {cond}')
        print(f'{SEP3}')
        print(f'  {"Domain":<15s}  {"TP(A→A)":>9s}  {"FN(A→B)":>9s}'
              f'  {"FP(B→A)":>9s}  {"TN(B→B)":>9s}'
              f'  {"Prec":>7s}  {"Rec":>7s}  {"F1":>7s}')
        print('  ' + '-' * 82)
        for domain in DOMAINS:
            r = all_results[cond].get(domain)
            if not r:
                continue
            cm = r['plan_cm']
            tn, fp = cm[0][0], cm[0][1]
            fn, tp = cm[1][0], cm[1][1]
            prec = tp / max(1, tp + fp)
            rec  = tp / max(1, tp + fn)
            f1   = 2 * prec * rec / max(1e-9, prec + rec)
            print(f'  {domain:<15s}  {tp:>9d}  {fn:>9d}'
                  f'  {fp:>9d}  {tn:>9d}'
                  f'  {prec:>7.4f}  {rec:>7.4f}  {f1:>7.4f}')

print('DIRECT CONDITIONS')
print_plan_cm(DIRECT_CONDS)
print()
print('STEPWISE CONDITIONS')
print_plan_cm(STEPWISE_CONDS)
# Out:
# DIRECT CONDITIONS
#
# ==========================================================================
# PLAN CM — FlanT5_Direct
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)     Prec      Rec       F1
#   ----------------------------------------------------------------------------------
#   blocksworld            151        168         10        145   0.9379   0.4734   0.6292
#   blocksworld_3           18         32          9         80   0.6667   0.3600   0.4675
#   mystery                  0        319          2        153   0.0000   0.0000   0.0000
#   mystery_3                0         50          1         38   0.0000   0.0000   0.0000
#   logistics                6         87          7        175   0.4615   0.0645   0.1132
#
# ==========================================================================
# PLAN CM — FlanT5_Direct_FT50
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)     Prec      Rec       F1
#   ----------------------------------------------------------------------------------
#   blocksworld              0        319          0        155   0.0000   0.0000   0.0000
#   blocksworld_3            0         50          0         89   0.0000   0.0000   0.0000
#   mystery                  0        319          0        155   0.0000   0.0000   0.0000
#   mystery_3                0         50          0         39   0.0000   0.0000   0.0000
#   logistics                0         93          0        182   0.0000   0.0000   0.0000
#
# ==========================================================================
# PLAN CM — FlanT5_Direct_FT_Random
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)     Prec      Rec       F1
#   ----------------------------------------------------------------------------------
#   blocksworld              0         64          0         31   0.0000   0.0000   0.0000
#   blocksworld_3            0         10          0         18   0.0000   0.0000   0.0000
#   mystery                  0         64          0         31   0.0000   0.0000   0.0000
#   mystery_3                0         10          0          8   0.0000   0.0000   0.0000
#   logistics                0         19          0         36   0.0000   0.0000   0.0000
#
# ==========================================================================
# PLAN CM — G_direct
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)     Prec      Rec       F1
#   ----------------------------------------------------------------------------------
#   blocksworld             49        269         12        142   0.8033   0.1541   0.2586
#   blocksworld_3           15         34         11         77   0.5769   0.3061   0.4000
#   mystery                  0        318          0        154   0.0000   0.0000   0.0000
#   mystery_3                1         48          0         38   1.0000   0.0204   0.0400
#   logistics                5         87          1        180   0.8333   0.0543   0.1020
#
# ==========================================================================
# PLAN CM — G5_direct
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)     Prec      Rec       F1
#   ----------------------------------------------------------------------------------
#   blocksworld            309          9         28        126   0.9169   0.9717   0.9435
#   blocksworld_3           48          1         13         75   0.7869   0.9796   0.8727
#   mystery                 63        255         22        132   0.7412   0.1981   0.3127
#   mystery_3                6         43          9         29   0.4000   0.1224   0.1875
#   logistics               64         28         60        121   0.5161   0.6957   0.5926
#
# STEPWISE CONDITIONS
#
# ==========================================================================
# PLAN CM — FlanT5_Stepwise
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)     Prec      Rec       F1
#   ----------------------------------------------------------------------------------
#   blocksworld              8        311          1        154   0.8889   0.0251   0.0488
#   blocksworld_3            0         50          1         88   0.0000   0.0000   0.0000
#   mystery                  0        319          0        155   0.0000   0.0000   0.0000
#   mystery_3                0         50          0         39   0.0000   0.0000   0.0000
#   logistics                0         93          0        182   0.0000   0.0000   0.0000
#
# ==========================================================================
# PLAN CM — FlanT5_Stepwise_FT_FOLIO
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)     Prec      Rec       F1
#   ----------------------------------------------------------------------------------
#   blocksworld             28        291          8        147   0.7778   0.0878   0.1577
#   blocksworld_3            9         41          8         81   0.5294   0.1800   0.2687
#   mystery                 57        262          8        147   0.8769   0.1787   0.2969
#   mystery_3               12         38          5         34   0.7059   0.2400   0.3582
#   logistics               46         47          2        180   0.9583   0.4946   0.6525
#
# ==========================================================================
# PLAN CM — FlanT5_Stepwise_FT_PB
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)     Prec      Rec       F1
#   ----------------------------------------------------------------------------------
#   blocksworld             43        276          1        154   0.9773   0.1348   0.2369
#   blocksworld_3           20         30          1         88   0.9524   0.4000   0.5634
#   mystery                  5        314          0        155   1.0000   0.0157   0.0309
#   mystery_3                1         49          0         39   1.0000   0.0200   0.0392
#   logistics               85          8          0        182   1.0000   0.9140   0.9551
#
# ==========================================================================
# PLAN CM — FlanT5_Stepwise_FT_Combined
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)     Prec      Rec       F1
#   ----------------------------------------------------------------------------------
#   blocksworld            319          0          8        147   0.9755   1.0000   0.9876
#   blocksworld_3           50          0          8         81   0.8621   1.0000   0.9259
#   mystery                121        198          7        148   0.9453   0.3793   0.5414
#   mystery_3               43          7          5         34   0.8958   0.8600   0.8776
#   logistics               88          5          1        181   0.9888   0.9462   0.9670
#
# ==========================================================================
# PLAN CM — G_stepwise
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)     Prec      Rec       F1
#   ----------------------------------------------------------------------------------
#   blocksworld            192        127          3        152   0.9846   0.6019   0.7471
#   blocksworld_3           40         10          4         85   0.9091   0.8000   0.8511
#   mystery                  0        319          0        155   0.0000   0.0000   0.0000
#   mystery_3                0         50          0         39   0.0000   0.0000   0.0000
#   logistics               12         81          0        182   1.0000   0.1290   0.2286
#
# ==========================================================================
# PLAN CM — G5_stepwise
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)     Prec      Rec       F1
#   ----------------------------------------------------------------------------------
#   blocksworld            309         10          0        155   1.0000   0.9687   0.9841
#   blocksworld_3           50          0          0         89   1.0000   1.0000   1.0000
#   mystery                127        192          1        154   0.9922   0.3981   0.5682
#   mystery_3               38         12          2         37   0.9500   0.7600   0.8444
#   logistics               89          4          0        182   1.0000   0.9570   0.9780

# %% [markdown]
# ## 5. Action-Level Confusion Matrices
#
# Columns: TP(A→A) FN(A→B) FP(B→A) TN(B→B)
# - A-recall = TP/(TP+FN): valid steps correctly passed
# - B-recall = TN/(TN+FP): invalid steps correctly caught

# %%
for cond in DIRECT_CONDS + STEPWISE_CONDS:
    if cond not in all_results:
        continue
    has_actions = any(
        all_results[cond][d].get('action_f1') is not None
        for d in DOMAINS if d in all_results[cond]
    )
    if not has_actions:
        continue

    print(f'\n{SEP3}')
    print(f'ACTION CM — {cond}')
    print(f'{SEP3}')
    print(f'  {"Domain":<15s}  {"TP(A→A)":>9s}  {"FN(A→B)":>9s}'
          f'  {"FP(B→A)":>9s}  {"TN(B→B)":>9s}'
          f'  {"F1mac":>6s}  {"A-rec":>6s}  {"B-rec":>6s}')
    print('  ' + '-' * 86)

    all_ag, all_ap = [], []
    for domain in DOMAINS:
        r  = all_results[cond].get(domain, {})
        ag = r.get('action_golds', [])
        ap = r.get('action_preds', [])
        if not ag:
            continue
        all_ag.extend(ag)
        all_ap.extend(ap)
        cm = confusion_matrix(ag, ap, labels=[0, 1])
        tn, fp, fn, tp = cm[0,0], cm[0,1], cm[1,0], cm[1,1]
        f1    = f1_score(ag, ap, average='macro', zero_division=0)
        a_rec = tp / max(1, tp + fn)
        b_rec = tn / max(1, tn + fp)
        print(f'  {domain:<15s}  {tp:>9d}  {fn:>9d}'
              f'  {fp:>9d}  {tn:>9d}'
              f'  {f1:>6.4f}  {a_rec:>6.4f}  {b_rec:>6.4f}')

    if all_ag:
        cm_all = confusion_matrix(all_ag, all_ap, labels=[0, 1])
        tn,fp,fn,tp = cm_all[0,0],cm_all[0,1],cm_all[1,0],cm_all[1,1]
        f1_all = f1_score(all_ag, all_ap, average='macro', zero_division=0)
        a_rec  = tp / max(1, tp + fn)
        b_rec  = tn / max(1, tn + fp)
        print('  ' + '-' * 86)
        print(f'  {"OVERALL":<15s}  {tp:>9d}  {fn:>9d}'
              f'  {fp:>9d}  {tn:>9d}'
              f'  {f1_all:>6.4f}  {a_rec:>6.4f}  {b_rec:>6.4f}')
# Out:
# ==========================================================================
# ACTION CM — G_direct
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)   F1mac   A-rec   B-rec
#   --------------------------------------------------------------------------------------
#   blocksworld           2295        301         32         79  0.6271  0.8841  0.7117
#   blocksworld_3          361         52         27         39  0.6991  0.8741  0.5909
#   mystery               2530         66         95         16  0.5675  0.9746  0.1441
#   mystery_3              223         52         14         13  0.5769  0.8109  0.4815
#   logistics             4316        182         18         66  0.6875  0.9595  0.7857
#   --------------------------------------------------------------------------------------
#   OVERALL               9725        653        186        213  0.6477  0.9371  0.5338
#
# ==========================================================================
# ACTION CM — FlanT5_Stepwise
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)   F1mac   A-rec   B-rec
#   --------------------------------------------------------------------------------------
#   blocksworld            420        347         62         50  0.4345  0.5476  0.4464
#   blocksworld_3          103         86         33         15  0.4176  0.5450  0.3125
#   mystery                  0        397          0         77  0.1397  0.0000  1.0000
#   mystery_3                0         72          0         17  0.1604  0.0000  1.0000
#   logistics               15        210          2         63  0.2484  0.0667  0.9692
#   --------------------------------------------------------------------------------------
#   OVERALL                538       1112         97        222  0.3697  0.3261  0.6959
#
# ==========================================================================
# ACTION CM — FlanT5_Stepwise_FT_FOLIO
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)   F1mac   A-rec   B-rec
#   --------------------------------------------------------------------------------------
#   blocksworld            520        328        102         10  0.3760  0.6132  0.0893
#   blocksworld_3          126         72         50          1  0.3450  0.6364  0.0196
#   mystery               1622        282         85         19  0.4961  0.8519  0.1827
#   mystery_3              165         42         25          1  0.4301  0.7971  0.0385
#   logistics             3202        100         70         11  0.5444  0.9697  0.1358
#   --------------------------------------------------------------------------------------
#   OVERALL               5635        824        332         42  0.4874  0.8724  0.1123
#
# ==========================================================================
# ACTION CM — FlanT5_Stepwise_FT_PB
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)   F1mac   A-rec   B-rec
#   --------------------------------------------------------------------------------------
#   blocksworld           1393        301         28         84  0.6162  0.8223  0.7500
#   blocksworld_3          346         46         10         48  0.7784  0.8827  0.8276
#   mystery                763        362         47         48  0.4894  0.6782  0.5053
#   mystery_3              112         61         14         10  0.4798  0.6474  0.4167
#   logistics             4323         14         53         32  0.7404  0.9968  0.3765
#   --------------------------------------------------------------------------------------
#   OVERALL               6937        784        152        222  0.6293  0.8985  0.5936
#
# ==========================================================================
# ACTION CM — FlanT5_Stepwise_FT_Combined
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)   F1mac   A-rec   B-rec
#   --------------------------------------------------------------------------------------
#   blocksworld           2607          0         71         41  0.7613  1.0000  0.3661
#   blocksworld_3          418          0         38         29  0.7803  1.0000  0.4328
#   mystery               1953        206         73         35  0.5670  0.9046  0.3241
#   mystery_3              262          8         25          3  0.5473  0.9704  0.1071
#   logistics             4486          5         72         13  0.6220  0.9989  0.1529
#   --------------------------------------------------------------------------------------
#   OVERALL               9726        219        279        121  0.6510  0.9780  0.3025
#
# ==========================================================================
# ACTION CM — G_stepwise
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)   F1mac   A-rec   B-rec
#   --------------------------------------------------------------------------------------
#   blocksworld           2120        132         18         94  0.7610  0.9414  0.8393
#   blocksworld_3          403         13         22         43  0.8346  0.9688  0.6615
#   mystery                109        387          0         83  0.3303  0.2198  1.0000
#   mystery_3               15         67          1         20  0.3382  0.1829  0.9524
#   logistics             1170        162          7         77  0.7047  0.8784  0.9167
#   --------------------------------------------------------------------------------------
#   OVERALL               3817        761         48        317  0.6718  0.8338  0.8685
#
# ==========================================================================
# ACTION CM — G5_stepwise
# ==========================================================================
#   Domain             TP(A→A)    FN(A→B)    FP(B→A)    TN(B→B)   F1mac   A-rec   B-rec
#   --------------------------------------------------------------------------------------
#   blocksworld           2595         11          0        113  0.9757  0.9958  1.0000
#   blocksworld_3          418          0          0         67  1.0000  1.0000  1.0000
#   mystery               2135        418          2        164  0.6745  0.8363  0.9880
#   mystery_3              257         18          3         27  0.8404  0.9345  0.9000
#   logistics             4487         14          0         87  0.9620  0.9969  1.0000
#   --------------------------------------------------------------------------------------
#   OVERALL               9892        461          5        458  0.8199  0.9555  0.9892

# %% [markdown]
# ## 6. Grouped Results: Non-Abstract vs Abstract Domains

# %%
NON_ABSTRACT = ['blocksworld', 'blocksworld_3', 'logistics']
ABSTRACT     = ['mystery', 'mystery_3']

METRICS = [
    ('plan_f1',          'Plan F1-macro'),
    ('plan_acc',         'Plan Accuracy'),
    ('action_f1',        'Action F1-macro'),
    ('action_acc',       'Action Accuracy'),
    ('failing_step_acc', 'Failing Step Accuracy'),
]

def group_mean(cond, domains, metric):
    vals = [all_results[cond].get(d, {}).get(metric)
            for d in domains if cond in all_results]
    vals = [v for v in vals if v is not None]
    return np.mean(vals) if vals else None

def print_grouped(cond_names, group_label):
    active = [c for c in cond_names if c in all_results]
    if not active:
        return
    print(f'\n{"-"*82}')
    print(f'{group_label}')
    print(f'{"-"*82}')
    for metric, label in METRICS:
        has_any = any(
            all_results.get(c, {}).get(d, {}).get(metric) is not None
            for c in active for d in DOMAINS
        )
        if not has_any:
            continue
        print(f'\n  {label}')
        print(f'  {"Condition":<40s}  {"Non-Abstract":>13s}  {"Abstract":>10s}')
        print('  ' + '-' * 67)
        for cond in active:
            na = group_mean(cond, NON_ABSTRACT, metric)
            ab = group_mean(cond, ABSTRACT,     metric)
            na_str = f'{na:.4f}' if na is not None else '   N/A'
            ab_str = f'{ab:.4f}' if ab is not None else '   N/A'
            print(f'  {cond:<40s}  {na_str:>13s}  {ab_str:>10s}')

print('=' * 82)
print('NON-ABSTRACT (bw, bw3, log)  vs  ABSTRACT (mys, mys3)')
print_grouped(DIRECT_CONDS,   'DIRECT CONDITIONS')
print_grouped(STEPWISE_CONDS, 'STEPWISE CONDITIONS')
# Out:
# ==================================================================================
# NON-ABSTRACT (bw, bw3, log)  vs  ABSTRACT (mys, mys3)
#
# ----------------------------------------------------------------------------------
# DIRECT CONDITIONS
# ----------------------------------------------------------------------------------
#
#   Plan F1-macro
#   Condition                                  Non-Abstract    Abstract
#   -------------------------------------------------------------------
#   FlanT5_Direct                                    0.5690      0.2716
#   FlanT5_Direct_FT50                               0.3450      0.2756
#   FlanT5_Direct_FT_Random                          0.3443      0.2768
#   G_direct                                         0.4734      0.2863
#   G5_direct                                        0.8215      0.3789
#
#   Plan Accuracy
#   Condition                                  Non-Abstract    Abstract
#   -------------------------------------------------------------------
#   FlanT5_Direct                                    0.6626      0.3749
#   FlanT5_Direct_FT50                               0.5430      0.3826
#   FlanT5_Direct_FT_Random                          0.5412      0.3853
#   G_direct                                         0.5846      0.3873
#   G5_direct                                        0.8324      0.4077
#
#   Action F1-macro
#   Condition                                  Non-Abstract    Abstract
#   -------------------------------------------------------------------
#   FlanT5_Direct                                       N/A         N/A
#   FlanT5_Direct_FT50                                  N/A         N/A
#   FlanT5_Direct_FT_Random                             N/A         N/A
#   G_direct                                         0.6712      0.5722
#   G5_direct                                           N/A         N/A
#
#   Action Accuracy
#   Condition                                  Non-Abstract    Abstract
#   -------------------------------------------------------------------
#   FlanT5_Direct                                       N/A         N/A
#   FlanT5_Direct_FT50                                  N/A         N/A
#   FlanT5_Direct_FT_Random                             N/A         N/A
#   G_direct                                         0.8895      0.8610
#   G5_direct                                           N/A         N/A
#
#   Failing Step Accuracy
#   Condition                                  Non-Abstract    Abstract
#   -------------------------------------------------------------------
#   FlanT5_Direct                                       N/A         N/A
#   FlanT5_Direct_FT50                                  N/A         N/A
#   FlanT5_Direct_FT_Random                             N/A         N/A
#   G_direct                                         0.6961      0.3128
#   G5_direct                                           N/A         N/A
#
# ----------------------------------------------------------------------------------
# STEPWISE CONDITIONS
# ----------------------------------------------------------------------------------
#
#   Plan F1-macro
#   Condition                                  Non-Abstract    Abstract
#   -------------------------------------------------------------------
#   FlanT5_Stepwise                                  0.3529      0.2756
#   FlanT5_Stepwise_FT_FOLIO                         0.5371      0.4473
#   FlanT5_Stepwise_FT_PB                            0.6851      0.2953
#   FlanT5_Stepwise_FT_Combined                      0.9651      0.7149
#   G_stepwise                                       0.7115      0.2756
#   G5_stepwise                                      0.9867      0.7171
#
#   Plan Accuracy
#   Condition                                  Non-Abstract    Abstract
#   -------------------------------------------------------------------
#   FlanT5_Stepwise                                  0.5456      0.3826
#   FlanT5_Stepwise_FT_FOLIO                         0.6128      0.4737
#   FlanT5_Stepwise_FT_PB                            0.7212      0.3935
#   FlanT5_Stepwise_FT_Combined                      0.9679      0.7164
#   G_stepwise                                       0.7768      0.3826
#   G5_stepwise                                      0.9881      0.7177
#
#   Action F1-macro
#   Condition                                  Non-Abstract    Abstract
#   -------------------------------------------------------------------
#   FlanT5_Stepwise                                  0.3668      0.1500
#   FlanT5_Stepwise_FT_FOLIO                         0.4218      0.4631
#   FlanT5_Stepwise_FT_PB                            0.7117      0.4846
#   FlanT5_Stepwise_FT_Combined                      0.7212      0.5572
#   G_stepwise                                       0.7668      0.3342
#   G5_stepwise                                      0.9792      0.7574
#
#   Action Accuracy
#   Condition                                  Non-Abstract    Abstract
#   -------------------------------------------------------------------
#   FlanT5_Stepwise                                  0.4339      0.1767
#   FlanT5_Stepwise_FT_FOLIO                         0.6706      0.7648
#   FlanT5_Stepwise_FT_PB                            0.8927      0.6421
#   FlanT5_Stepwise_FT_Combined                      0.9596      0.8831
#   G_stepwise                                       0.9148      0.3357
#   G5_stepwise                                      0.9976      0.8883
#
#   Failing Step Accuracy
#   Condition                                  Non-Abstract    Abstract
#   -------------------------------------------------------------------
#   FlanT5_Stepwise                                  0.7334      0.6473
#   FlanT5_Stepwise_FT_FOLIO                         0.5974      0.5185
#   FlanT5_Stepwise_FT_PB                            0.9474      0.7264
#   FlanT5_Stepwise_FT_Combined                      1.0000      0.9487
#   G_stepwise                                          N/A         N/A
#   G5_stepwise                                      1.0000      0.9822
